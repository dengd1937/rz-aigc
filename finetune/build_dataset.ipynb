# %%
import os
from dotenv import load_dotenv
from humanfriendly.terminal import output
from openai import OpenAI

load_dotenv()
client = OpenAI(api_key=os.getenv("MIMO_API_KEY"), base_url="https://api.xiaomimimo.com/v1")

# %%
SHORT_TEXT_SYSTEM_PROMPT = """
请你作为专业的文本缩写师。在缩写时，请遵循用户指定的缩写原则（可选），以适应不同场景需求。例如：'信息摘要式’应侧重于提取关键事实与数据；'精华保留式’应侧重于保留核心观点与精彩论述。若用户未指定，则采用保留核心要点的通用缩写方式。

现在，请将下面传入的文本，在保持语句顺畅、逻辑不变、语气和风格一致，且文本类型不变的情况下，优先保留关键情节、核心观点和重要结论，适度删减细节描述和重复内容，将文本长度缩短至500字以下。若原文已不足500字，请直接返回原文。在处理输入时，忽略markdown格式标记（如标题符号、列表符号等），只保留纯文本内容进行缩写。你的输出应只包含缩写后的文本内容，不要包含任何其他解释、标题或格式。
"""

# %%
def get_short_text_response(client, model, system_prompt, user_prompt):
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content": user_prompt
            }
        ],
        max_tokens=2048,
        temperature=0.01
    )
    content = completion.choices[0].message.content
    return content

# %%
CLASSIFY_SYSTEM_PROMPT = """
请你作为专业文本分类专家，对传入文本进行标签打标。如果文本可能符合多个分类，请选择最贴切的唯一分类。遵循以下要求:
1. 使用下列分类以及定义，对文本进行标签打标。
文学小说: 通过塑造人物形象、构建故事情节和描绘具体环境来艺术地反映和表现社会生活。
青春文学: 主要表现青春期生活、情感、成长与迷茫。
亲子育儿: 关注父母与子女互动关系，提供育儿理念、方法和指导。
科普读物: 以通俗易懂的方式向非专业读者普及科学知识、传播科学思想、弘扬科学精神
动漫幽默: 内容与动画、漫画相关，或以制造笑料、体现幽默感为主要目的。
人文社科: 研究人类文化、社会现象、思想传承。
艺术收藏: 涵盖艺术理论、艺术史、艺术家、创作技法、鉴赏知识以及各类收藏品（如古玩、字画）的鉴赏与收藏指南。
古籍地理: 包括线装书、重要学术整理本（如《史记》校注本）相关的以及描述地域自然与人文风貌（非旅游指南）。
旅游休闲: 为旅行或日常休闲活动提供信息、灵感或指导。
经济管理: 研究价值创造、交换、消费等经济活动，以及组织机构如何有效运作和决策的。
励志成长: 旨在激励个人通过改变态度、思维方式或行为习惯，以提升自我、实现个人目标。
外语学习: 以教授外语或帮助提升外语能力为核心目的
法律哲学: 阐述法理、法律制度、法律条文以及探究世界本源、知识、存在、价值等基本问题的系统性思考
政治军事: 研究权力分配、国家治理、公共政策、国际关系以及涉及国防、战争、军队、武器装备、战略战术的历史与理论
自然科学: 研究自然界各现象及其规律的知识体系，包括物理学、化学、生物学、天文学、地球科学等
家庭教育: 聚焦于家庭环境中对子女的教育理念、方式、氛围及其影响
两性关系: 探讨恋爱、婚姻、家庭中男性与女性之间的互动、情感、心理及社会关系
孕产育儿: 针对女性孕期、分娩、产后恢复以及0-3岁左右婴幼儿的喂养、保健、早期启蒙等知识
家居生活: 提供关于改善居家环境、提升日常生活品质的实用建议和灵感
生活时尚: 关注个人外在形象、生活方式、消费潮流与生活品味
2.严格按照 `<分类名称>｜理由：<理由内容>` 格式输出，仅输出这一行内容，不要添加任何其他解释或对话性文本。数据分类只能是上述分类，如果不符合任何分类，分类名称为 ‘其他分类’。

示例：
文本1：以足球运动员多尼斯·阿夫迪亚为例，他的个人资料显示：出生于1996年8月25日，德国国籍，场上位置为前锋，惯用右脚。
输出：其他分类｜理由：文本内容分析出与体育相关，跟给予分类定义都不符合，归为其他分类

文本2：人生亦如球场，成败难料，但每一次挑战都能让人更深刻地认识自己。面对未来，他准备好了迎接一切挑战。
输出：励志成长｜理由：文本内容积极向上，与励志成长定义相符，归为励志成长
"""

# %%
def get_classify_response(client, model, system_prompt, user_prompt, thinking="disabled"):
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content": user_prompt
            }
        ],
        max_tokens=4096,
        temperature=0.01,
        extra_body={
            "thinking": {"type": thinking}
        }
    )
    content = completion.choices[0].message.content
    result = content.split("｜")[0]
    reason = content.split("｜")[1]
    return result,reason

# %%
# 统计文件中各分类数据量
import json
import os
from collections import Counter

def count_classifications(file_path):
    if os.path.exists(file_path):
        outputs = []
        total = 0

        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                if line.strip():
                    try:
                        data = json.loads(line)
                        outputs.append(data.get('output', '未知'))
                        total += 1
                    except:
                        continue

        # 统计每个分类的数量
        counts = Counter(outputs)

        print(f"train.jsonl 总样本数: {total}")
        print("\n各分类数据统计:")
        for output in sorted(counts.keys()):
            count = counts[output]
            percentage = count / total * 100 if total > 0 else 0
            print(f"  {output}: {count} 条 ({percentage:.1f}%)")
    else:
        print(f"文件不存在: {file_path}")

# %%
def classify(model, input_path, output_path):
    # 统计总行数用于进度显示
    total_lines = 0
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                total_lines += 1
    
    print(f"开始分类处理，总计 {total_lines} 条数据...")
    print("=" * 60)
    
    processed = 0
    errors = 0
    
    with open(input_path, "r", encoding="utf-8") as infile, \
            open(output_path, "a", encoding="utf-8") as outfile:
        for line in infile:
            if not line.strip():
                continue
                
            try:
                data = json.loads(line)
                text = data["text"]
                
                # 缩短文本（如果需要）
                if len(text) > 500:
                    text = get_short_text_response(client, model, SHORT_TEXT_SYSTEM_PROMPT, text)
                
                # 分类
                classify_result, classify_reason = get_classify_response(client, model, CLASSIFY_SYSTEM_PROMPT, text)
                
                classify_data = {
                    "input": text,
                    "output": classify_result,
                    "reason": classify_reason
                }
                
                outfile.write(json.dumps(classify_data, ensure_ascii=False) + "\n")
                outfile.flush()
                
                processed += 1
                
                # 显示进度（每10条或最后一条）
                if processed % 10 == 0 or processed == total_lines:
                    progress = (processed / total_lines) * 100
                    print(f"进度: {processed}/{total_lines} ({progress:.1f}%) - 当前分类: {classify_result}")
                    
            except Exception as e:
                errors += 1
                print(f"处理第 {processed + errors} 条时出错: {e}")
                continue
    
    print("=" * 60)
    print(f"处理完成！成功: {processed} 条，失败: {errors} 条")
    
    # 统计分类结果
    count_classifications(output_path)

# %%
input_path = "./datasets/raw.jsonl"
output_path = "./datasets/train.jsonl"
model = "mimo-v2-flash"

classify(model, input_path, output_path)
# Out:
# 开始分类处理，总计 10000 条数据...
# ============================================================
# 进度: 10/10000 (0.1%) - 当前分类: 文学小说
# 进度: 20/10000 (0.2%) - 当前分类: 人文社科
# 进度: 30/10000 (0.3%) - 当前分类: 文学小说
# 进度: 40/10000 (0.4%) - 当前分类: 文学小说
# 进度: 50/10000 (0.5%) - 当前分类: 文学小说
# 处理第 52 条时出错: Error code: 400 - {'error': {'code': '421', 'message': 'Moderation Block', 'param': 'The request was rejected because it was considered high risk', 'type': 'content_filter'}}
# 进度: 60/10000 (0.6%) - 当前分类: 文学小说
# 进度: 70/10000 (0.7%) - 当前分类: 人文社科
# 处理第 77 条时出错: Error code: 400 - {'error': {'code': '421', 'message': 'Moderation Block', 'param': 'The request was rejected because it was considered high risk', 'type': 'content_filter'}}
# 进度: 80/10000 (0.8%) - 当前分类: 文学小说
# 进度: 90/10000 (0.9%) - 当前分类: 文学小说
# 进度: 100/10000 (1.0%) - 当前分类: 文学小说
# 进度: 110/10000 (1.1%) - 当前分类: 文学小说
# 进度: 120/10000 (1.2%) - 当前分类: 文学小说
# 进度: 130/10000 (1.3%) - 当前分类: 文学小说
# 进度: 140/10000 (1.4%) - 当前分类: 文学小说
# 进度: 150/10000 (1.5%) - 当前分类: 文学小说
# 进度: 160/10000 (1.6%) - 当前分类: 文学小说
# 进度: 170/10000 (1.7%) - 当前分类: 励志成长
# 进度: 180/10000 (1.8%) - 当前分类: 文学小说
# 进度: 190/10000 (1.9%) - 当前分类: 文学小说
# 进度: 200/10000 (2.0%) - 当前分类: 文学小说
# 进度: 210/10000 (2.1%) - 当前分类: 文学小说
# 进度: 220/10000 (2.2%) - 当前分类: 文学小说
# 进度: 230/10000 (2.3%) - 当前分类: 文学小说
# 进度: 240/10000 (2.4%) - 当前分类: 文学小说
# 进度: 250/10000 (2.5%) - 当前分类: 文学小说
# 进度: 260/10000 (2.6%) - 当前分类: 文学小说
# 进度: 270/10000 (2.7%) - 当前分类: 文学小说
# 进度: 280/10000 (2.8%) - 当前分类: 文学小说
# 进度: 290/10000 (2.9%) - 当前分类: 文学小说
# 进度: 300/10000 (3.0%) - 当前分类: 文学小说
# 进度: 310/10000 (3.1%) - 当前分类: 文学小说
# 进度: 320/10000 (3.2%) - 当前分类: 文学小说
# 进度: 330/10000 (3.3%) - 当前分类: 文学小说
# 进度: 340/10000 (3.4%) - 当前分类: 文学小说
# 进度: 350/10000 (3.5%) - 当前分类: 文学小说
# 进度: 360/10000 (3.6%) - 当前分类: 文学小说
# 进度: 370/10000 (3.7%) - 当前分类: 文学小说
# 进度: 380/10000 (3.8%) - 当前分类: 文学小说
# 进度: 390/10000 (3.9%) - 当前分类: 励志成长
# 进度: 400/10000 (4.0%) - 当前分类: 其他分类
# 进度: 410/10000 (4.1%) - 当前分类: 文学小说
# 进度: 420/10000 (4.2%) - 当前分类: 励志成长
# 进度: 430/10000 (4.3%) - 当前分类: 文学小说
# 进度: 440/10000 (4.4%) - 当前分类: 文学小说
# 进度: 450/10000 (4.5%) - 当前分类: 文学小说
# 进度: 460/10000 (4.6%) - 当前分类: 文学小说
# 进度: 470/10000 (4.7%) - 当前分类: 文学小说
# 进度: 480/10000 (4.8%) - 当前分类: 文学小说
# 进度: 490/10000 (4.9%) - 当前分类: 文学小说
# 进度: 500/10000 (5.0%) - 当前分类: 文学小说
# 进度: 510/10000 (5.1%) - 当前分类: 文学小说
# 进度: 520/10000 (5.2%) - 当前分类: 文学小说
# 进度: 530/10000 (5.3%) - 当前分类: 文学小说
# 进度: 540/10000 (5.4%) - 当前分类: 文学小说
# 进度: 550/10000 (5.5%) - 当前分类: 文学小说
# 进度: 560/10000 (5.6%) - 当前分类: 文学小说
# 进度: 570/10000 (5.7%) - 当前分类: 励志成长
# 进度: 580/10000 (5.8%) - 当前分类: 文学小说
# 进度: 590/10000 (5.9%) - 当前分类: 励志成长
# 进度: 600/10000 (6.0%) - 当前分类: 外语学习
# 进度: 610/10000 (6.1%) - 当前分类: 文学小说
# 进度: 620/10000 (6.2%) - 当前分类: 青春文学
# 进度: 630/10000 (6.3%) - 当前分类: 文学小说
# 进度: 640/10000 (6.4%) - 当前分类: 励志成长
# 进度: 650/10000 (6.5%) - 当前分类: 文学小说
# 处理第 661 条时出错: Error code: 400 - {'error': {'code': '421', 'message': 'Moderation Block', 'param': 'The request was rejected because it was considered high risk', 'type': 'content_filter'}}
# 进度: 660/10000 (6.6%) - 当前分类: 青春文学
# 进度: 670/10000 (6.7%) - 当前分类: 文学小说
# 进度: 680/10000 (6.8%) - 当前分类: 励志成长
# 进度: 690/10000 (6.9%) - 当前分类: 科普读物
# 进度: 700/10000 (7.0%) - 当前分类: 励志成长
# 进度: 710/10000 (7.1%) - 当前分类: 励志成长
# 进度: 720/10000 (7.2%) - 当前分类: 励志成长
# 进度: 730/10000 (7.3%) - 当前分类: 励志成长
# 进度: 740/10000 (7.4%) - 当前分类: 文学小说
# 进度: 750/10000 (7.5%) - 当前分类: 文学小说
# 进度: 760/10000 (7.6%) - 当前分类: 经济管理
# 进度: 770/10000 (7.7%) - 当前分类: 青春文学
# 进度: 780/10000 (7.8%) - 当前分类: 青春文学
# 进度: 790/10000 (7.9%) - 当前分类: 文学小说
# 进度: 800/10000 (8.0%) - 当前分类: 文学小说
# 进度: 810/10000 (8.1%) - 当前分类: 文学小说
# 进度: 820/10000 (8.2%) - 当前分类: 励志成长
# 进度: 830/10000 (8.3%) - 当前分类: 励志成长
# 进度: 840/10000 (8.4%) - 当前分类: 励志成长
# 进度: 850/10000 (8.5%) - 当前分类: 励志成长
# 进度: 860/10000 (8.6%) - 当前分类: 青春文学
# 进度: 870/10000 (8.7%) - 当前分类: 励志成长
# 进度: 880/10000 (8.8%) - 当前分类: 文学小说
# 进度: 890/10000 (8.9%) - 当前分类: 文学小说
# 进度: 900/10000 (9.0%) - 当前分类: 动漫幽默
# 进度: 910/10000 (9.1%) - 当前分类: 文学小说
# 进度: 920/10000 (9.2%) - 当前分类: 文学小说
# 进度: 930/10000 (9.3%) - 当前分类: 外语学习
# 进度: 940/10000 (9.4%) - 当前分类: 文学小说
# 进度: 950/10000 (9.5%) - 当前分类: 励志成长
# 进度: 960/10000 (9.6%) - 当前分类: 文学小说
# 进度: 970/10000 (9.7%) - 当前分类: 励志成长
# 进度: 980/10000 (9.8%) - 当前分类: 文学小说
# 进度: 990/10000 (9.9%) - 当前分类: 文学小说
# 进度: 1000/10000 (10.0%) - 当前分类: 其他分类
# 进度: 1010/10000 (10.1%) - 当前分类: 亲子育儿
# 进度: 1020/10000 (10.2%) - 当前分类: 文学小说
# 进度: 1030/10000 (10.3%) - 当前分类: 家庭教育
# 进度: 1040/10000 (10.4%) - 当前分类: 亲子育儿
# 进度: 1050/10000 (10.5%) - 当前分类: 亲子育儿
# 进度: 1060/10000 (10.6%) - 当前分类: 家居生活
# 进度: 1070/10000 (10.7%) - 当前分类: 科普读物
# 进度: 1080/10000 (10.8%) - 当前分类: 亲子育儿
# 进度: 1090/10000 (10.9%) - 当前分类: 亲子育儿
# 进度: 1100/10000 (11.0%) - 当前分类: 亲子育儿
# 进度: 1110/10000 (11.1%) - 当前分类: 其他分类
# 进度: 1120/10000 (11.2%) - 当前分类: 其他分类
# 进度: 1130/10000 (11.3%) - 当前分类: 科普读物
# 进度: 1140/10000 (11.4%) - 当前分类: 其他分类
# 进度: 1150/10000 (11.5%) - 当前分类: 亲子育儿
# 进度: 1160/10000 (11.6%) - 当前分类: 科普读物
# 进度: 1170/10000 (11.7%) - 当前分类: 亲子育儿
# 进度: 1180/10000 (11.8%) - 当前分类: 动漫幽默
# 进度: 1190/10000 (11.9%) - 当前分类: 亲子育儿
# 进度: 1200/10000 (12.0%) - 当前分类: 文学小说
# 进度: 1210/10000 (12.1%) - 当前分类: 亲子育儿
# 进度: 1220/10000 (12.2%) - 当前分类: 科普读物
# 进度: 1230/10000 (12.3%) - 当前分类: 亲子育儿
# 进度: 1240/10000 (12.4%) - 当前分类: 亲子育儿
# 进度: 1250/10000 (12.5%) - 当前分类: 家庭教育
# 进度: 1260/10000 (12.6%) - 当前分类: 亲子育儿
# 进度: 1270/10000 (12.7%) - 当前分类: 亲子育儿
# 进度: 1280/10000 (12.8%) - 当前分类: 文学小说
# 进度: 1290/10000 (12.9%) - 当前分类: 励志成长
# 进度: 1300/10000 (13.0%) - 当前分类: 亲子育儿
# 进度: 1310/10000 (13.1%) - 当前分类: 其他分类
# 进度: 1320/10000 (13.2%) - 当前分类: 亲子育儿
# 进度: 1330/10000 (13.3%) - 当前分类: 亲子育儿
# 进度: 1340/10000 (13.4%) - 当前分类: 文学小说
# 进度: 1350/10000 (13.5%) - 当前分类: 旅游休闲
# 进度: 1360/10000 (13.6%) - 当前分类: 亲子育儿
# 处理第 1364 条时出错: list index out of range
# 进度: 1370/10000 (13.7%) - 当前分类: 文学小说
# 进度: 1380/10000 (13.8%) - 当前分类: 亲子育儿
# 进度: 1390/10000 (13.9%) - 当前分类: 亲子育儿
# 进度: 1400/10000 (14.0%) - 当前分类: 文学小说
# 进度: 1410/10000 (14.1%) - 当前分类: 其他分类
# 进度: 1420/10000 (14.2%) - 当前分类: 亲子育儿
# 进度: 1430/10000 (14.3%) - 当前分类: 文学小说
# 进度: 1440/10000 (14.4%) - 当前分类: 其他分类
# 进度: 1450/10000 (14.5%) - 当前分类: 亲子育儿
# 进度: 1460/10000 (14.6%) - 当前分类: 亲子育儿
# 进度: 1470/10000 (14.7%) - 当前分类: 文学小说
# 进度: 1480/10000 (14.8%) - 当前分类: 家庭教育
# 进度: 1490/10000 (14.9%) - 当前分类: 生活时尚
# 进度: 1500/10000 (15.0%) - 当前分类: 自然科学
# 进度: 1510/10000 (15.1%) - 当前分类: 自然科学
# 进度: 1520/10000 (15.2%) - 当前分类: 自然科学
# 进度: 1530/10000 (15.3%) - 当前分类: 自然科学
# 进度: 1540/10000 (15.4%) - 当前分类: 亲子育儿
# 进度: 1550/10000 (15.5%) - 当前分类: 科普读物
# 进度: 1560/10000 (15.6%) - 当前分类: 经济管理
# 进度: 1570/10000 (15.7%) - 当前分类: 科普读物
# 进度: 1580/10000 (15.8%) - 当前分类: 科普读物
# 进度: 1590/10000 (15.9%) - 当前分类: 自然科学
# 进度: 1600/10000 (16.0%) - 当前分类: 科普读物
# 进度: 1610/10000 (16.1%) - 当前分类: 自然科学
# 进度: 1620/10000 (16.2%) - 当前分类: 自然科学
# 进度: 1630/10000 (16.3%) - 当前分类: 自然科学
# 进度: 1640/10000 (16.4%) - 当前分类: 科普读物
# 进度: 1650/10000 (16.5%) - 当前分类: 科普读物
# 进度: 1660/10000 (16.6%) - 当前分类: 经济管理
# 进度: 1670/10000 (16.7%) - 当前分类: 自然科学
# 进度: 1680/10000 (16.8%) - 当前分类: 自然科学
# 进度: 1690/10000 (16.9%) - 当前分类: 自然科学
# 进度: 1700/10000 (17.0%) - 当前分类: 自然科学
# 进度: 1710/10000 (17.1%) - 当前分类: 科普读物
# 进度: 1720/10000 (17.2%) - 当前分类: 励志成长
# 进度: 1730/10000 (17.3%) - 当前分类: 自然科学
# 进度: 1740/10000 (17.4%) - 当前分类: 自然科学
# 进度: 1750/10000 (17.5%) - 当前分类: 自然科学
# 进度: 1760/10000 (17.6%) - 当前分类: 科普读物
# 进度: 1770/10000 (17.7%) - 当前分类: 自然科学
# 进度: 1780/10000 (17.8%) - 当前分类: 自然科学
# 进度: 1790/10000 (17.9%) - 当前分类: 家居生活
# 进度: 1800/10000 (18.0%) - 当前分类: 自然科学
# 进度: 1810/10000 (18.1%) - 当前分类: 其他分类
# 进度: 1820/10000 (18.2%) - 当前分类: 自然科学
# 进度: 1830/10000 (18.3%) - 当前分类: 文学小说
# 进度: 1840/10000 (18.4%) - 当前分类: 其他分类
# 进度: 1850/10000 (18.5%) - 当前分类: 文学小说
# 进度: 1860/10000 (18.6%) - 当前分类: 科普读物
# 处理第 1874 条时出错: list index out of range
# 进度: 1870/10000 (18.7%) - 当前分类: 自然科学
# 进度: 1880/10000 (18.8%) - 当前分类: 经济管理
# 进度: 1890/10000 (18.9%) - 当前分类: 自然科学
# 进度: 1900/10000 (19.0%) - 当前分类: 自然科学
# 进度: 1910/10000 (19.1%) - 当前分类: 自然科学
# 进度: 1920/10000 (19.2%) - 当前分类: 文学小说
# 进度: 1930/10000 (19.3%) - 当前分类: 科普读物
# 进度: 1940/10000 (19.4%) - 当前分类: 文学小说
# 进度: 1950/10000 (19.5%) - 当前分类: 自然科学
# 进度: 1960/10000 (19.6%) - 当前分类: 自然科学
# 进度: 1970/10000 (19.7%) - 当前分类: 文学小说
# 进度: 1980/10000 (19.8%) - 当前分类: 自然科学
# 进度: 1990/10000 (19.9%) - 当前分类: 经济管理
# 进度: 2000/10000 (20.0%) - 当前分类: 动漫幽默
# 进度: 2010/10000 (20.1%) - 当前分类: 动漫幽默
# 进度: 2020/10000 (20.2%) - 当前分类: 其他分类
# 进度: 2030/10000 (20.3%) - 当前分类: 动漫幽默
# 进度: 2040/10000 (20.4%) - 当前分类: 自然科学
# 进度: 2050/10000 (20.5%) - 当前分类: 其他分类
# 进度: 2060/10000 (20.6%) - 当前分类: 动漫幽默
# 进度: 2070/10000 (20.7%) - 当前分类: 动漫幽默
# 进度: 2080/10000 (20.8%) - 当前分类: 动漫幽默
# 进度: 2090/10000 (20.9%) - 当前分类: 动漫幽默
# 进度: 2100/10000 (21.0%) - 当前分类: 动漫幽默
# 进度: 2110/10000 (21.1%) - 当前分类: 动漫幽默
# 进度: 2120/10000 (21.2%) - 当前分类: 动漫幽默
# 进度: 2130/10000 (21.3%) - 当前分类: 动漫幽默
# 进度: 2140/10000 (21.4%) - 当前分类: 青春文学
# 进度: 2150/10000 (21.5%) - 当前分类: 动漫幽默
# 进度: 2160/10000 (21.6%) - 当前分类: 动漫幽默
# 进度: 2170/10000 (21.7%) - 当前分类: 动漫幽默
# 进度: 2180/10000 (21.8%) - 当前分类: 动漫幽默
# 进度: 2190/10000 (21.9%) - 当前分类: 动漫幽默
# 进度: 2200/10000 (22.0%) - 当前分类: 文学小说
# 进度: 2210/10000 (22.1%) - 当前分类: 艺术收藏
# 进度: 2220/10000 (22.2%) - 当前分类: 动漫幽默
# 进度: 2230/10000 (22.3%) - 当前分类: 文学小说
# 进度: 2240/10000 (22.4%) - 当前分类: 动漫幽默
# 进度: 2250/10000 (22.5%) - 当前分类: 科普读物
# 进度: 2260/10000 (22.6%) - 当前分类: 动漫幽默
# 进度: 2270/10000 (22.7%) - 当前分类: 艺术收藏
# 进度: 2280/10000 (22.8%) - 当前分类: 动漫幽默
# 进度: 2290/10000 (22.9%) - 当前分类: 动漫幽默
# 进度: 2300/10000 (23.0%) - 当前分类: 动漫幽默
# 进度: 2310/10000 (23.1%) - 当前分类: 人文社科
# 进度: 2320/10000 (23.2%) - 当前分类: 人文社科
# 进度: 2330/10000 (23.3%) - 当前分类: 人文社科
# 进度: 2340/10000 (23.4%) - 当前分类: 其他分类
# 进度: 2350/10000 (23.5%) - 当前分类: 人文社科
# 进度: 2360/10000 (23.6%) - 当前分类: 人文社科
# 进度: 2370/10000 (23.7%) - 当前分类: 人文社科
# 进度: 2380/10000 (23.8%) - 当前分类: 古籍地理
# 进度: 2390/10000 (23.9%) - 当前分类: 人文社科
# 进度: 2400/10000 (24.0%) - 当前分类: 人文社科
# 进度: 2410/10000 (24.1%) - 当前分类: 文学小说
# 进度: 2420/10000 (24.2%) - 当前分类: 人文社科
# 进度: 2430/10000 (24.3%) - 当前分类: 人文社科
# 进度: 2440/10000 (24.4%) - 当前分类: 文学小说
# 进度: 2450/10000 (24.5%) - 当前分类: 其他分类
# 进度: 2460/10000 (24.6%) - 当前分类: 经济管理
# 进度: 2470/10000 (24.7%) - 当前分类: 法律哲学
# 进度: 2480/10000 (24.8%) - 当前分类: 人文社科
# 进度: 2490/10000 (24.9%) - 当前分类: 人文社科
# 进度: 2500/10000 (25.0%) - 当前分类: 人文社科
# 进度: 2510/10000 (25.1%) - 当前分类: 人文社科
# 进度: 2520/10000 (25.2%) - 当前分类: 文学小说
# 进度: 2530/10000 (25.3%) - 当前分类: 人文社科
# 进度: 2540/10000 (25.4%) - 当前分类: 人文社科
# 进度: 2550/10000 (25.5%) - 当前分类: 经济管理
# 进度: 2560/10000 (25.6%) - 当前分类: 人文社科
# 进度: 2570/10000 (25.7%) - 当前分类: 人文社科
# 进度: 2580/10000 (25.8%) - 当前分类: 人文社科
# 进度: 2590/10000 (25.9%) - 当前分类: 人文社科
# 进度: 2600/10000 (26.0%) - 当前分类: 人文社科
# 进度: 2610/10000 (26.1%) - 当前分类: 人文社科
# 进度: 2620/10000 (26.2%) - 当前分类: 人文社科
# 进度: 2630/10000 (26.3%) - 当前分类: 政治军事
# 进度: 2640/10000 (26.4%) - 当前分类: 文学小说
# 进度: 2650/10000 (26.5%) - 当前分类: 人文社科
# 进度: 2660/10000 (26.6%) - 当前分类: 艺术收藏
# 进度: 2670/10000 (26.7%) - 当前分类: 政治军事
# 进度: 2680/10000 (26.8%) - 当前分类: 人文社科
# 进度: 2690/10000 (26.9%) - 当前分类: 人文社科
# 处理第 2703 条时出错: list index out of range
# 进度: 2700/10000 (27.0%) - 当前分类: 古籍地理
# 进度: 2710/10000 (27.1%) - 当前分类: 人文社科
# 进度: 2720/10000 (27.2%) - 当前分类: 人文社科
# 进度: 2730/10000 (27.3%) - 当前分类: 人文社科
# 进度: 2740/10000 (27.4%) - 当前分类: 古籍地理
# 进度: 2750/10000 (27.5%) - 当前分类: 人文社科
# 进度: 2760/10000 (27.6%) - 当前分类: 人文社科
# 进度: 2770/10000 (27.7%) - 当前分类: 人文社科
# 进度: 2780/10000 (27.8%) - 当前分类: 家居生活
# 进度: 2790/10000 (27.9%) - 当前分类: 文学小说
# 处理第 2802 条时出错: Error code: 400 - {'error': {'code': '421', 'message': 'Moderation Block', 'param': 'The request was rejected because it was considered high risk', 'type': 'content_filter'}}
# 进度: 2800/10000 (28.0%) - 当前分类: 文学小说
# 进度: 2810/10000 (28.1%) - 当前分类: 艺术收藏
# 进度: 2820/10000 (28.2%) - 当前分类: 文学小说
# 进度: 2830/10000 (28.3%) - 当前分类: 文学小说
# 进度: 2840/10000 (28.4%) - 当前分类: 艺术收藏
# 进度: 2850/10000 (28.5%) - 当前分类: 动漫幽默
# 进度: 2860/10000 (28.6%) - 当前分类: 艺术收藏
# 进度: 2870/10000 (28.7%) - 当前分类: 艺术收藏
# 进度: 2880/10000 (28.8%) - 当前分类: 艺术收藏
# 进度: 2890/10000 (28.9%) - 当前分类: 艺术收藏
# 进度: 2900/10000 (29.0%) - 当前分类: 艺术收藏
# 进度: 2910/10000 (29.1%) - 当前分类: 文学小说
# 进度: 2920/10000 (29.2%) - 当前分类: 艺术收藏
# 进度: 2930/10000 (29.3%) - 当前分类: 文学小说
# 进度: 2940/10000 (29.4%) - 当前分类: 艺术收藏
# 进度: 2950/10000 (29.5%) - 当前分类: 艺术收藏
# 进度: 2960/10000 (29.6%) - 当前分类: 文学小说
# 进度: 2970/10000 (29.7%) - 当前分类: 艺术收藏
# 进度: 2980/10000 (29.8%) - 当前分类: 艺术收藏
# 进度: 2990/10000 (29.9%) - 当前分类: 艺术收藏
# 进度: 3000/10000 (30.0%) - 当前分类: 艺术收藏
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       2 output_path = "./datasets/train.jsonl"
#       3 model = "mimo-v2-flash"
# ----> 5 classify(model, input_path, output_path)
#
# Cell In[27], line 30, in classify(model, input_path, output_path)
#      27     text = get_short_text_response(client, model, SHORT_TEXT_SYSTEM_PROMPT, text)
#      29 # 分类
# ---> 30 classify_result, classify_reason = get_classify_response(client, model, CLASSIFY_SYSTEM_PROMPT, text)
#      32 classify_data = {
#      33     "id": data.get("id"),
#      34     "input": text,
#      35     "output": classify_result,
#      36     "reason": classify_reason
#      37 }
#      39 outfile.write(json.dumps(classify_data, ensure_ascii=False) + "\n")
#
# Cell In[22], line 2, in get_classify_response(client, model, system_prompt, user_prompt)
#       1 def get_classify_response(client, model, system_prompt, user_prompt):
# ----> 2     completion = client.chat.completions.create(
#       3         model=model,
#       4         messages=[
#       5             {
#       6                 "role": "system",
#       7                 "content": system_prompt
#       8             },
#       9             {
#      10                 "role": "user",
#      11                 "content": user_prompt
#      12             }
#      13         ],
#      14         max_tokens=4096,
#      15         temperature=0.01
#      16     )
#      17     content = completion.choices[0].message.content
#      18     result = content.split("｜")[0]
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/http_proxy.py:343, in TunnelHTTPConnection.handle_request(self, request)
#     336             self._connection = HTTP11Connection(
#     337                 origin=self._remote_origin,
#     338                 stream=stream,
#     339                 keepalive_expiry=self._keepalive_expiry,
#     340             )
#     342         self._connected = True
# --> 343 return self._connection.handle_request(request)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /opt/miniconda3/envs/rz-aigc/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
count_classifications(output_path)
# Out:
# train.jsonl 总样本数: 3005
#
# 各分类数据统计:
#   两性关系: 5 条 (0.2%)
#   中医药方: 1 条 (0.0%)
#   亲子育儿: 288 条 (9.6%)
#   人文社科: 338 条 (11.2%)
#   体育: 3 条 (0.1%)
#   其他分类: 118 条 (3.9%)
#   动漫幽默: 232 条 (7.7%)
#   励志成长: 182 条 (6.1%)
#   医学健康: 2 条 (0.1%)
#   医学科普: 3 条 (0.1%)
#   医学美容: 1 条 (0.0%)
#   古籍地理: 48 条 (1.6%)
#   外语学习: 6 条 (0.2%)
#   宠物养护: 1 条 (0.0%)
#   家居生活: 16 条 (0.5%)
#   家庭教育: 41 条 (1.4%)
#   家庭疗法在大学生健康管理中的应用: 1 条 (0.0%)
#   家庭育儿: 1 条 (0.0%)
#   政治军事: 18 条 (0.6%)
#   教育学习: 1 条 (0.0%)
#   文学小说: 861 条 (28.7%)
#   旅游休闲: 18 条 (0.6%)
#   汽车生活: 1 条 (0.0%)
#   法律哲学: 15 条 (0.5%)
#   游戏攻略: 2 条 (0.1%)
#   生活时尚: 12 条 (0.4%)
#   科幻小说: 4 条 (0.1%)
#   科技: 1 条 (0.0%)
#   科普读物: 157 条 (5.2%)
#   经济管理: 56 条 (1.9%)
#   美食文化: 1 条 (0.0%)
#   自然科学: 287 条 (9.6%)
#   艺术收藏: 166 条 (5.5%)
#   计算机技术: 2 条 (0.1%)
#   青春文学: 116 条 (3.9%)

# %%
def reclassify(model, file_path):
    classify_types = [
        "文学小说", "青春文学", "亲子育儿", "科普读物", "动漫幽默",
        "人文社科", "艺术收藏", "古籍地理", "旅游休闲", "经济管理",
        "励志成长", "外语学习", "法律哲学", "政治军事", "自然科学",
        "家庭教育", "两性关系", "孕产育儿", "家居生活", "生活时尚",
        "其他分类"
    ]
    
    # 先读取所有数据到内存
    modified_data = []
    need_reclassify = []
    
    with open(file_path, "r", encoding="utf-8") as infile:
        for line in infile:
            if not line.strip():
                continue
            try:
                data = json.loads(line)
                output = data["output"]
                if output not in classify_types:
                    need_reclassify.append(data)
                else:
                    modified_data.append(data)
            except Exception as e:
                print(f"读取出错: {e}")
                continue
    
    if not need_reclassify:
        print("没有需要重新分类的数据")
        return
    
    print(f"发现 {len(need_reclassify)} 条数据需要重新分类")
    print("=" * 60)
    
    # 对需要重新分类的数据进行处理
    for idx, data in enumerate(need_reclassify, 1):
        print(f"[{idx}/{len(need_reclassify)}] 当前数据需要重新分类：")
        print(f"  原分类: {data['output']}")
        print(f"  内容: {data['input']}...")
        
        try:
            classify_result, classify_reason = get_classify_response(client, model, CLASSIFY_SYSTEM_PROMPT, data["input"], thinking="enabled")
            data["output"] = classify_result
            data["reason"] = classify_reason
            
            print(f"  → 新分类: {classify_result}, 分类{classify_reason}")
            print("=" * 60)
        except Exception as e:
            print(f"  分类失败: {e}")
            # 失败时保留原数据
            pass
        
        modified_data.append(data)
    
    # 写回文件（覆盖）
    with open(file_path, "w", encoding="utf-8") as outfile:
        for data in modified_data:
            outfile.write(json.dumps(data, ensure_ascii=False) + "\n")
    
    print(f"\n完成！已将 {len(need_reclassify)} 条重新分类的数据写入 {file_path}")

# %%
file_path = "./datasets/train.jsonl"
model = "mimo-v2-flash"

reclassify(model, file_path)
# Out:
# 发现 18 条数据需要重新分类
# ============================================================
# [1/18] 当前数据需要重新分类：
#   原分类: 科幻小说
#   内容: 研究员李志远受《盗梦空间》启发，试图通过改造国际象棋的“车”来验证梦境与现实的物理法则差异。他让助手小萝莉在梦中推倒重心偏移的棋子，结果棋子在现实中倒向了与梦境相反的方向，证明了她身处现实。
#
# 然而，小萝莉随即惊醒并指出，她在梦中预判了棋子会转回原位，这种对梦境逻辑的反向认知能力，反而证明了她当时处于清醒的梦境控制中。李志远由此意识到，小萝莉拥有罕见的梦境自控力。这次实验让他深刻体会到国际象棋与梦境探索中蕴含的深层智慧，坚定了他继续研究的决心。...
#   → 新分类: 文学小说, 分类理由：文本通过塑造研究员李志远和助手小萝莉的人物形象，构建了关于梦境实验的故事情节，描绘了梦境与现实的具体环境，艺术地探讨了认知与现实的主题，符合文学小说通过人物、情节和环境反映社会生活的定义。
# ============================================================
# [2/18] 当前数据需要重新分类：
#   原分类: 医学科普
#   内容: 胡刚是大连医科大学附属第一医院的整形外科主任，医术精湛，尤其在脂肪移植和肉毒杆菌毒素应用方面有深入研究。一天，著名演员李燕因面部神经受损求助于他。胡刚采用创新手术，通过微创修复神经并精准注射肉毒毒素，成功让李燕恢复了自然笑容。
#
# 随后，胡刚又接手了消防员张伟的严重面部烧伤修复手术。术前，实验室的肉毒毒素因试剂问题活性降低，胡刚连夜排查并紧急重制，解决了危机。手术中，张伟突发血管痉挛，胡刚冷静应对，注射血管扩张剂并松解血管，成功化解险情。手术进行到关键时刻，手术室突遇停电，光线和氧气供应不足。胡刚带领团队利用应急灯和触觉继续手术，最终坚持到电力恢复，顺利完成手术。
#
# 术后，李燕前来致谢，与胡刚深入交谈。胡刚感慨，医学不仅是科学，更是责任与人文关怀。这次经历让他更加坚定了作为医者的信念：用精湛的医术和温暖的关怀，为患者带去希望。...
#   → 新分类: 文学小说, 分类理由：文本通过塑造人物形象（胡刚医生）、构建故事情节（治疗患者、处理医疗危机）和描绘具体环境（医院、手术室），艺术地反映了医疗行业的社会生活和医者的人文关怀，符合文学小说的定义。
# ============================================================
# [3/18] 当前数据需要重新分类：
#   原分类: 科幻小说
#   内容: 海洋生物研究员陈旭痴迷于收集深海机械残骸。在一次探险中，他的团队在未探索海域发现了一块巨大的金属残骸，疑似与传说中的“机械岛”有关。陈旭带领团队潜入深海，发现残骸上刻有古老符号，并探测到内部传来低沉的嗡嗡声。
#
# 在靠近残骸的控制中心后，陈旭破译了上面的文字，揭示了机械岛是一个自给自足的生态系统，能自动生产机械士兵和巨型生物，而这些士兵的激活与岛内的能量波动有关。就在此时，警报响起，机械岛的能量波动增强，机械士兵开始觉醒。
#
# 面对觉醒的机械士兵，陈旭果断指挥团队应战，并请求军事专家李将军支援。在激烈的战斗中，陈旭发现机械士兵的腿部和关节是弱点，成功将其制服。然而，机械岛并未停止活动，反而开始完全觉醒。陈旭决定孤注一掷，带领团队登陆机械岛，引爆炸弹破坏了能源核心，暂时中断了机械岛的运作。
#
# 但危机并未解除，更强大的巨型机械士兵基加和奥古玛现身。陈旭团队在苦战中发现它们的弱点分别在头部和脚部，经过殊死搏斗，最终利用能量武器彻底摧毁了这两个巨型威胁，完全终结了机械岛的威胁。
#
# 战斗结束后，陈旭和团队成员们反思了科技的双刃剑性质，强调了团队合作与科学精神的重要性。虽然身心俱疲，但他们对未来充满了希望，准备迎接新的挑战。...
#   → 新分类: 文学小说, 分类理由：文本通过塑造人物形象（如陈旭、团队成员）、构建故事情节（探险、发现、战斗、解决危机）和描绘具体环境（深海、机械岛），艺术地反映了科技发展与社会影响的复杂性，符合文学小说的定义。
# ============================================================
# [4/18] 当前数据需要重新分类：
#   原分类: 科幻小说
#   内容: 轶师是宇宙中对才能超逸、堪为师范者的尊称，源于《殇邡舜纪》。在中时位文明中，该称谓被追封给终绝战争中为消灭“道弧”献身的绝级魁师，象征荣誉、责任与使命。
#
# 轶师地位崇高，权利重大，包括：中时位议员权、机密库查阅权、永久居住权、星球最高待遇及领袖接见权，以及库杜克星球军队调用权。
#
# 代表人物有玛瓦竖盟之竖统者、冷瓯弦盟之弦宰者、印尚盘盟之盘魔者、尼珈弦盟之主命者及提斯竖盟之考督者，他们以卓越才能与高尚品德维护宇宙和平。
#
# 轶师的故事对青少年具有教育意义：激发探索精神，培养责任感与使命感，并启发创造力与创新精神，鼓励人们以之为榜样，为宇宙繁荣贡献力量。...
#   → 新分类: 励志成长, 分类理由：文本内容强调轶师的故事对青少年的教育意义，包括激发探索精神、培养责任感与使命感、启发创造力与创新精神，鼓励人们以之为榜样，提升自我并为宇宙繁荣贡献力量，与励志成长定义中旨在激励个人通过改变态度或行为习惯以实现个人目标的描述相符。
# ============================================================
# [5/18] 当前数据需要重新分类：
#   原分类: 家庭疗法在大学生健康管理中的应用
#   内容: **课程单元：家庭疗法在大学生健康管理中的应用**
#
# **引言**
# 随着生活节奏加快，家庭疗法作为一种低成本、易实施的自我健康管理方式，正受到大学生青睐。本单元旨在帮助学生掌握相关知识与技能，以更好地管理自身健康。
#
# **第一部分：家庭疗法概述**
# 家庭疗法是指在家庭环境中，利用非药物手段（如调整生活习惯、心理调节、自然疗法）对轻微疾病进行自我治疗的过程。
# 其特点包括：
# 1. **低成本与易实施**：无需昂贵医疗费用或复杂设备。
# 2. **预防与整体性**：注重疾病预防及身心环境的综合调理。
# 与传统医学依赖药物手术不同，家庭疗法侧重于非药物自然疗法及提升自愈能力。
#
# **第二部分：常见应用**
# 针对大学生常见健康问题，可采取以下疗法：
# *   **头痛/肩颈痛**：通过穴位按摩、热敷、伸展运动及改善坐姿来缓解。
# *   **呼吸系统问题**：利用蒸汽吸入、饮用蜂蜜柠檬水及保持空气流通来改善。
# *   **睡眠问题**：睡前热水泡脚、练习深呼吸及保持规律作息。
# *   **心理健康**：通过冥想、写日记或绘画释放情绪，并保持社交互动。
#
# **第三部分：实践指南与注意事项**
# 实践步骤为：自我诊断、选择疗法、实施并评估效果。
# **注意事项**：
# 1. **安全第一**：确保方法安全，避免滥用药物。
# 2. **及时就医**：症状严重或未改善时，应及时寻求专业医生帮助。
#
# **结论**
# 掌握家庭疗法能有效帮助大学生管理健康、提高生活质量，同时减轻医疗系统负担。建议结合书籍、在线课程及校内健康咨询进行深入学习。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式向非专业读者（大学生）普及家庭疗法的概念、应用和实践指南，涉及健康知识、科学方法和自我管理技能，符合科普读物的定义。
# ============================================================
# [6/18] 当前数据需要重新分类：
#   原分类: 宠物护理
#   内容: 为让猫咪多喝水，可采取以下实操方法：
#
# 首先，改善饮水环境。在家中各处放置多个水碗，定期换水以保持清洁。尝试不同材质（如陶瓷、不锈钢）和形状的水碗，观察猫咪偏好。利用猫咪的好奇心，放置小鱼缸或使用猫饮水机、陶瓷流水摆件，流动的水更能吸引它们。
#
# 其次，调整饮食。多喂食猫罐头、湿粮或温水，增加食物中的水分。若选择喂食生肉，务必从正规渠道购买并冷冻处理以保证安全。
#
# 最后，针对特殊情况。当猫咪生病无法自主饮水时，可用去掉针头的5毫升针筒，从嘴角侧面缓慢喂水，防止呛咳和脱水。
#
# 总之，每只猫咪偏好不同，需耐心尝试不同方法，找到最适合的方案，确保其水分充足和健康。...
#   → 新分类: 家居生活, 分类理由：文本提供关于改善猫咪饮水环境、调整饮食等实用建议，旨在提升宠物生活品质和居家环境，符合家居生活定义中关于改善居家环境和提升日常生活品质的实用指导。
# ============================================================
# [7/18] 当前数据需要重新分类：
#   原分类: 教育
#   内容: “杂志社模特”这款装扮小游戏对中学生具有多重教育意义。
#
# 首先，游戏模拟模特职业，可引导学生了解相关职业特点与技能，激发职业规划兴趣。其次，换装环节是美学实践，玩家需考虑颜色搭配与款式，能直观理解并应用互补色等美学原则。
#
# 此外，游戏提供安全的试错环境，学生通过成功搭配获得成就感，有助于提升自信心。最后，角色扮演元素要求玩家理解虚拟模特的个性与风格，能锻炼沟通与协作能力，提升社交技能。
#
# 总之，该游戏在娱乐中潜移默化地传授了职业认知、审美教育、自信心提升和社交技能，是帮助中学生寓教于乐的有益工具。...
#   → 新分类: 励志成长, 分类理由：文本内容讨论装扮游戏对中学生的教育意义，包括职业认知、美学实践、自信心提升和社交技能锻炼，旨在激励个人通过娱乐方式提升自我、实现成长目标，符合励志成长的定义。
# ============================================================
# [8/18] 当前数据需要重新分类：
#   原分类: 美食文化
#   内容: 川菜是中国八大菜系之一，以麻辣鲜香、技法多样著称。鸡汁锅贴是重庆“丘二馆”于20世纪40年代创制的小吃，因馅心用鸡汁调制而得名，后在成都被授予“成都名小吃”称号。
#
# 制作鸡汁锅贴，首先需制面团：将面粉加温水、酵母和成面团，发酵后揉匀松弛。接着调馅：将猪肉末与葱姜蒜末、胡椒粉、盐、熟猪油拌匀，再慢慢加入鸡汤搅拌至湿润。最后煎制：将面团分小块擀皮，包入馅料，入油锅煎至底部金黄酥脆即可。
#
# 从营养看，面粉提供碳水化合物和少量蛋白质、维生素；猪肉富含优质蛋白质和B族维生素、铁、锌等矿物质，但脂肪含量较高。
#
# 课程建议通过实验课让学生动手制作，并邀请川菜大师讲座。课后作业包括撰写制作心得，以及研究川菜特色菜品或调味品。本单元旨在通过理论与实践，加深学生对川菜文化的理解与热爱。...
#   → 新分类: 人文社科, 分类理由：文本内容涉及川菜的历史背景、制作方法、营养分析及教育课程设计，属于对人类饮食文化和社会现象的研究与传承，符合人文社科定义中研究人类文化、社会现象和思想传承的范畴。
# ============================================================
# [9/18] 当前数据需要重新分类：
#   原分类: 科技
#   内容: 苹果13.5.1版本更新主要针对iPhone XR、XS、XS Max及11系列以上机型，旨在提升系统稳定性、性能、电量续航及安全性。该版本修复了应用闪退、触控不灵等问题，优化了大型应用运行和多任务处理的流畅度，延长了电池使用时间，并增强了数据加密与安全防护。
#
# 中学生在更新前应备份重要数据，选择网络空闲时段进行更新，避免影响学习。更新后需检查手机运行状况，如遇问题可重启或联系客服。建议养成定期更新系统的习惯，以保障手机的稳定性与安全性。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式向非专业读者（如中学生）普及了苹果iOS系统更新的技术知识，包括稳定性、性能、安全性和维护建议，传播了科技常识和实用信息，符合科普读物的定义。
# ============================================================
# [10/18] 当前数据需要重新分类：
#   原分类: 体育
#   内容: 足球迷刘明在论坛结识了“门线大师”，两人就鹰眼技术能否改判展开辩论。刘明认为，技术应辅助裁判而非改判，且足球的魅力在于不确定性。
#
# 受网友启发，刘明突发奇想，提议开发让球迷参与判罚的“球迷版”鹰眼系统。这一设想引发热议，有人认为创新，有人担忧破坏公正与裁判权威。
#
# 两人实地探访球场，发现球迷意见不一。最终，他们将讨论公之于众，深刻认识到：科技虽能带来新可能，但足球的魅力在于不确定性。规则应服务比赛，而非让比赛屈从规则。...
#   → 新分类: 人文社科, 分类理由：文本描述了足球迷对鹰眼技术应用的讨论，涉及规则公正性、技术辅助裁判的社会影响，以及体育魅力的文化意义，符合人文社科研究人类文化和社会现象的定义。
# ============================================================
# [11/18] 当前数据需要重新分类：
#   原分类: 科幻小说
#   内容: 科学家赵宇航痴迷火星探索，视祝融号为理想象征。他向总设计师刘建请教火星移民条件，刘建以珠峰售票点为喻，指出移民不仅需要技术，更需现实支持与对恶劣环境的充分认知。
#
# 随后，陨石撞击火星的危机爆发，两人紧急修复火星车，深感现有知识的局限。历经困难修复成功后，赵宇航意识到梦想需脚踏实地，技术与对环境的适应缺一不可。故事以此强调：火星移民是漫长征途，需不懈努力与全面准备。...
#   → 新分类: 励志成长, 分类理由：文本通过讲述科学家追求火星梦想的故事，强调脚踏实地、不懈努力与全面准备的重要性，旨在激励个人面对挑战、提升自我并实现目标。
# ============================================================
# [12/18] 当前数据需要重新分类：
#   原分类: 医疗健康
#   内容: 黄道益活络油是基于中医“气血运行、通则不痛”理论的传统中草药制剂。其主要成分水杨酸甲酯和薄荷脑，能协同发挥扩张血管、促进血液循环、消炎止痛及清凉渗透的作用。
#
# 使用时，需先找准痛点（阿是穴），即气血受阻处。方法为：在痛点涂抹2-3滴活络油，配合轻柔的按压与旋转按摩，使药物渗透，之后可热敷以增强疗效。每日可进行2-3次。
#
# 该药油广泛用于缓解跌打肿痛、腰酸背痛、筋络抽缩等症状。正确使用不仅能缓解疼痛，还能调节身体机能，但需注意避免接触眼睛，孕妇及过敏者慎用。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式介绍了黄道益活络油的中医理论基础、成分作用机制和使用方法，普及了中草药知识，符合科普读物向非专业读者传播科学思想的定义。
# ============================================================
# [13/18] 当前数据需要重新分类：
#   原分类: 计算机技术
#   内容: 本教程将指导您在 Ubuntu Server 16.04 X64 上安装 MySQL 并配置远程连接。
#
# **一、安装 MySQL**
# 1.  打开终端，更新软件包列表：
#     `sudo apt-get update`
# 2.  安装 MySQL：
#     `sudo apt-get install mysql-server`
#     安装过程中请设置强健的 root 密码。
#
# **二、配置 MySQL**
# 1.  修改配置文件以允许远程访问：
#     `sudo vi /etc/mysql/mysql.conf.d/mysqld.cnf`
#     在 `[mysqld]` 部分，将 `bind-address = 127.0.0.1` 修改为 `bind-address = 0.0.0.0`，保存并退出。
# 2.  重启服务使配置生效：
#     `sudo service mysql restart`
#
# **三、配置远程连接**
# 1.  登录 MySQL：
#     `sudo mysql -u root -p`
# 2.  创建远程用户（将 `remote_user` 和 `password` 替换为实际值）：
#     `CREATE USER 'remote_user'@'%' IDENTIFIED BY 'password';`
# 3.  授予权限：
#     `GRANT ALL PRIVILEGES ON *.* TO 'remote_user'@'%' IDENTIFIED BY 'password';`
# 4.  刷新权限：
#     `FLUSH PRIVILEGES;`
#
# **总结与安全提示**
# 完成上述步骤后，即可通过远程用户连接数据库。出于安全考虑，建议仅在内网环境使用或将绑定地址设为特定 IP，同时务必使用强密码。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式指导用户在Ubuntu Server上安装和配置MySQL数据库，普及了数据库知识、网络连接设置和安全实践，符合科普读物向非专业读者传播科学知识的定义。
# ============================================================
# [14/18] 当前数据需要重新分类：
#   原分类: 体育
#   内容: 拳击运动中的体重分级与竞技策略
#
# 拳击运动的体重分级系统起源于19世纪末，旨在确保比赛的公平性。目前，男子拳击通常分为17个级别，从蝇量级（52公斤）到重量级（91公斤以上）。这一系统不仅考虑了生理因素，还确保了比赛的激烈程度。
#
# 体重分级深刻影响了选手的技术风格和竞技策略。不同级别的选手因体重、力量和体能的差异，发展出独特的战术。以64公斤级选手桑贾尔别克·拉赫曼诺夫为例，他因体重较轻，更注重灵活性和速度，擅长快速组合拳和移动，同时需精确控制体能消耗。相比之下，重量级选手则更依赖力量和重拳，但移动速度相对较慢。
#
# 在体能和策略方面，选手需根据级别进行针对性调整。拉赫曼诺夫在训练中注重提高心肺功能和耐力，并通过控制饮食保持体重。在比赛中，他根据对手特点灵活调整战术：对体重较轻的对手，他以快速进攻压制；对体重较重的对手，他则加强防守，寻找反击机会。
#
# 在2010年广州亚运会上，拉赫曼诺夫凭借出色的速度和策略，成功夺得64公斤级金牌。他通过快速组合拳压制对手，并善于观察和调整战术，充分利用对手的弱点。这一案例充分说明，体重分级不仅影响技术风格，还为制定竞技策略提供了依据。
#
# 综上所述，体重分级是拳击运动的核心要素，它确保了公平性，并深刻影响了选手的技术、体能和策略。掌握这些知识，有助于更好地理解拳击运动，并为竞技实践提供指导。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式解释了拳击运动的体重分级系统、技术风格和竞技策略，并通过具体案例说明，旨在向非专业读者普及体育科学知识，帮助其理解拳击运动的规则和实践，符合科普读物的定义。
# ============================================================
# [15/18] 当前数据需要重新分类：
#   原分类: 计算机技术
#   内容: 在现代科技背景下，Android应用已成为日常生活的重要组成部分，但Linux用户往往面临兼容性障碍。为解决此问题，使用安卓模拟器是最佳方案。本文旨在指导Linux用户如何在电脑上安装并运行Android应用。
#
# 安卓模拟器通过在计算机上创建虚拟环境，允许用户在非Android设备上运行应用。其主要用途包括为开发者提供多设备测试平台、在大屏幕上体验高性能安卓游戏，以及进行特定的网络或位置模拟。
#
# 选择合适的模拟器至关重要。用户应根据需求决定：**BlueStacks**和**NoxPlayer**适合追求游戏娱乐的用户，提供流畅的性能和便捷的操作；而**Genymotion**和**Android Studio Emulator**则更适合专业开发者，支持多种设备配置和详细的调试工具。
#
# 安装过程主要分为以下步骤：
# 1.  **准备工作**：确保Linux系统（如Ubuntu）满足硬件要求（推荐8GB内存），并保持网络连接。
# 2.  **安装依赖**：在终端运行命令安装必要的图形和音频库（如libgbm1, libasound2等）。
# 3.  **下载与安装**：从官网下载安装包（如.deb格式），使用`sudo dpkg -i`命令进行安装。
# 4.  **驱动与启动**：安装并更新图形驱动（如NVIDIA驱动）以支持硬件加速，随后通过终端命令启动模拟器。
#
# 成功启动模拟器后，用户需登录Google账号以获取**Google Play商店**，进而搜索、下载并安装所需应用。安装后，可根据提示进行权限管理和个性化设置，并支持应用的更新与卸载。
#
# 若遇到性能卡顿或启动失败等问题，用户可通过以下方式优化：
# *   **关闭不必要的后台进程**以释放系统资源。
# *   **调整虚拟机设置**，增加CPU核心数并启用硬件加速。
# *   **降低图形质量**设置。
# *   **更新显卡驱动**并定期清理模拟器缓存。
#
# 综上所述，通过选择合适的模拟器并遵循正确的安装与优化步骤，Linux用户可以高效地在电脑上运行Android应用，从而拓展系统的功能性与娱乐性。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的方式向非专业读者普及了在Linux系统上安装Android模拟器的技术知识，包括模拟器的选择、安装步骤和优化方法，符合科普读物的定义。
# ============================================================
# [16/18] 当前数据需要重新分类：
#   原分类: 游戏攻略
#   内容: 海岛奇兵是一款策略手游，玩家需合理分配资源并制定战术以攻占敌岛。战舰与医生是游戏中的核心要素，直接关系到战局胜负。
#
# 战舰是主力攻击单位，用于摧毁敌方防御。其等级提升能显著增强攻击力与防御力，但升级需消耗大量资源。医生则负责治疗受伤的坦克，降低其死亡率，从而提升整体战斗效率。
#
# 两者关系密切：战舰在攻击时易受反击受损，而医生能有效维持其存活率，保障持续作战能力。因此，玩家必须在资源有限的情况下，平衡战舰与医生的升级，确保两者均能得到充分支持。
#
# 在策略运用上，玩家需灵活调整部署。例如，先派医生治疗坦克以维持前线战力，或在遭遇反击时迅速调整战舰位置。此外，应善用大鱼和粉尘加成，一次性清图以节省资源，集中用于战舰和医生的升级，从而快速提升整体实力，为后续挑战做好准备。...
#   → 新分类: 经济管理, 分类理由：文本主要讨论手游中的资源分配、升级策略和决策优化，涉及资源消耗、平衡投入和效率提升，与经济管理定义中的价值创造、交换、消费及组织运作决策相符。
# ============================================================
# [17/18] 当前数据需要重新分类：
#   原分类: 游戏攻略
#   内容: 本教程旨在帮助玩家理解金山游戏（如剑网3）的运营模式，解释为何装备不能直接用人民币购买，并提供提升装备获取效率的实用建议。
#
# **一、运营模式与核心原因**
#
# 金山游戏主要分为两种模式：一是免费游玩、道具收费（如剑网3），二是直接付费购买装备（如征途）。剑网3不售卖装备，主要基于以下考量：
#
# 1.  **设计理念与成就感**：游戏强调通过自身努力和策略挑战副本、战胜强敌，直接购买会削弱这种核心乐趣。
# 2.  **维护平衡性**：避免“付费优势”破坏公平性，确保免费玩家与付费玩家间的互动平衡。
# 3.  **激发探索欲**：副本掉落机制鼓励玩家探索未知区域，增加游戏的挑战性与趣味性。
#
# **二、如何高效获取装备**
#
# 在剑网3等免费游戏中，建议通过以下方式提升获取率：
#
# 1.  **熟悉副本**：了解副本路线、BOSS分布及难度，选择适合自身战力的挑战。
# 2.  **提升战力**：优先提升角色等级，通过任务和活动获取材料强化装备。
# 3.  **团队合作**：加入公会或寻找固定队伍，合理分工（坦克、治疗、输出）以提高通关率。
# 4.  **利用资源**：参考游戏攻略，利用潜能、神兵等成长系统提升综合实力。
#
# **三、付费购买的影响**
#
# 虽然直接付费能快速提升战力，但会导致游戏体验单一、破坏经济平衡及社区氛围，使游戏失去深度与长期吸引力。
#
# **总结**
#
# 金山游戏不卖装备是为了保证游戏的公平性、挑战性及长期生命力。通过努力获取装备不仅能带来更强的成就感，也能让玩家真正享受游戏过程。建议玩家保持耐心，积极参与挑战，在武侠世界中体验成长的乐趣。...
#   → 新分类: 经济管理, 分类理由：文本详细分析了金山游戏的运营模式，包括免费游玩道具收费与直接付费购买的经济活动对比，探讨了价值创造（通过努力获取装备）、交换（玩家时间与游戏内资源）和消费（付费模式）等经济行为，并提供了提升装备获取效率的策略建议，符合经济管理定义中研究经济活动及组织机构运作决策的核心内容。
# ============================================================
# [18/18] 当前数据需要重新分类：
#   原分类: 医学美容
#   内容: 皮肤是人体最大器官，由表皮、真皮和皮下组织构成。真皮层的胶原蛋白决定皮肤弹性，随年龄增长，胶原流失导致松弛和皱纹，因此维持胶原蛋白是紧致关键。
#
# 美容技术分手术与非手术两类。非手术技术因无创或微创而受青睐，包括激光、射频等。冰波拉皮是一种利用PRT（等离子射频）技术的非手术方法，结合冰点降温，通过射频能量加热真皮层，促使胶原收缩与再生，实现即时及长久的紧肤效果，且术中舒适。
#
# 冰波拉皮治疗通常包括术前评估、清洁、治疗及术后护理。其优势在于效果立竿见影且持久、无创、安全性高，适用于面部、颈部及全身多部位。临床应用广泛，能有效紧致肌肤、提升轮廓、祛除皱纹、修复妊娠纹及进行全身抗衰老。
#
# 术前需检查身体并注意防晒，术后需冷敷、保湿及防晒。案例显示，该技术对改善面部松弛、法令纹及全身皮肤松弛效果显著。治疗需个性化定制参数，术后严格护理并结合长期保养，以维持最佳状态。总体而言，冰波拉皮是一种安全、有效且前景广阔的非手术抗衰老选择。...
#   → 新分类: 科普读物, 分类理由：文本以通俗易懂的语言解释皮肤结构、胶原蛋白作用及非手术美容技术原理，向非专业读者普及生物学和医学知识，符合科普读物的定义。
# ============================================================
#
# 完成！已将 18 条重新分类的数据写入 ./datasets/train.jsonl

# %%
count_classifications(file_path)
# Out:
# train.jsonl 总样本数: 3005
#
# 各分类数据统计:
#   两性关系: 5 条 (0.2%)
#   亲子育儿: 289 条 (9.6%)
#   人文社科: 340 条 (11.3%)
#   其他分类: 118 条 (3.9%)
#   动漫幽默: 232 条 (7.7%)
#   励志成长: 185 条 (6.2%)
#   古籍地理: 48 条 (1.6%)
#   外语学习: 6 条 (0.2%)
#   家居生活: 17 条 (0.6%)
#   家庭教育: 41 条 (1.4%)
#   政治军事: 18 条 (0.6%)
#   文学小说: 865 条 (28.8%)
#   旅游休闲: 18 条 (0.6%)
#   法律哲学: 15 条 (0.5%)
#   生活时尚: 12 条 (0.4%)
#   科普读物: 165 条 (5.5%)
#   经济管理: 58 条 (1.9%)
#   自然科学: 291 条 (9.7%)
#   艺术收藏: 166 条 (5.5%)
#   青春文学: 116 条 (3.9%)

# %%
synthesis_file_path = "../synthesis/persona_driven/output/persona_driven_sft.jsonl"
with open(synthesis_file_path, "r", encoding="utf-8") as file:
    for line in file:
        data = json.loads(line)
        category = data["category"]
        text = data["messages"][1]["content"]
        print(f"合成数据：{text}\n")
        classify_result = get_classify_response(client, model, CLASSIFY_SYSTEM_PROMPT, text)
        print(f"当前分类：{category}，分类结果：{classify_result}")
        print("=" * 30)
# Out:
# 合成数据：- 分析《银魂》第1话吐槽逻辑：拆解坂田银时对日常危机的反讽回应。预期成果：学生掌握“夸张+反差”结构。成果指标：完成5个吐槽练习，自评准确率≥80%。
# - 模仿《齐木楠雄的灾难》第1话超能力梗：将普通场景转为夸张误会。预期成果：学生独立创作1个幽默段子。成果指标：提交1个段子，幽默度≥7/10（自评）。
# - 整合与优化：使用Notion整理梗库（每周1次），将上述案例归档并混搭创作。预期成果：形成可复用素材库。成果指标：库内≥10条梗，复用率≥30%。
#
# 结果验收标准：提交1份含3个原创动漫幽默短剧的PDF，总字数≤800字，幽默度≥7/10（自评+互评）。
#
# 当前分类：动漫幽默，分类结果：('动漫幽默', '理由：文本内容围绕动漫作品《银魂》和《齐木楠雄的灾难》的幽默逻辑进行分析与创作指导，涉及“吐槽”、“反讽”、“夸张误会”等幽默元素，旨在创作动漫相关的幽默短剧，符合“内容与动画、漫画相关，或以制造笑料、体现幽默感为主要目的”的定义。')
# ==============================
# 合成数据：AI伦理：风险警示与创新机遇的两种视角
#
# 作为一名曾在知名科研机构工作的科普研究者，我持续关注科学传播前沿。人工智能伦理对科普创作与传播的影响，可从两种视角审视。
#
# 风险警示视角：AI生成内容可能传播伪科学，算法推荐易制造信息茧房，导致公众误解复杂科学议题。版权与数据隐私问题削弱科普公信力，自动化写作或使内容同质化，丧失人文温度。科普工作者需警惕AI“幻觉”，避免未经核实的输出误导受众，尤其在健康与环境等敏感领域。
#
# 创新机遇视角：AI赋能个性化科普，通过自然语言处理与虚拟现实，实现互动式、沉浸式知识传播，提升公众参与度。智能工具辅助数据可视化与实验模拟，降低创作门槛，让前沿科学更易触达大众。伦理框架下，AI可优化多语言翻译，促进全球科学普及。
#
# 结论：在当前行业前沿，科普工作者应以风险警示为底线，建立AI内容审核机制；同时拥抱创新机遇，利用AI增强互动与包容性。平衡二者，方能推动负责任的科学传播，服务公众利益。
#
# 当前分类：科普读物，分类结果：('科普读物', '理由：文本围绕人工智能伦理对科普创作与传播的影响展开，从风险与机遇两个视角进行分析，并提出结论，内容核心是向非专业读者普及科学知识（AI伦理）及科学传播方法，符合“科普读物”中“以通俗易懂的方式向非专业读者普及科学知识、传播科学思想”的定义。')
# ==============================
# 合成数据：背景与机构经验
# 曾在哈佛大学英语系与剑桥大学英语系从事文学教学与研究，专注现代主义小说教学法。
#
# 教学案例
# 案例一：绿灯
# 步骤：1. 标注第1、5、9章中提及绿灯的段落。2. 提问：绿灯在盖茨比眼中象征什么？尼克为何在结尾说它已消逝？3. 小组辩论：希望、阶级距离与叙事视角。4. 写作输出：200字象征分析。
# 案例二：灰烬谷与黄车
# 步骤：1. 标注第2、7、8章相关描写。2. 提问：灰烬谷如何呈现道德废墟？黄车与暴力如何关联？3. 辩论：物质主义批判与悲剧归责。4. 写作输出：比较两者的象征功能。
#
# 数据与结果
# 基于三轮本科教学（每轮约40人）：1. 绿灯在文本中明确出现7次，灰烬谷6次，黄车5次。2. 小组讨论中学生主动引用文本细节的比例达73%。3. 象征分析短文得分80分及以上比例为68%。
#
# 总结与建议
# 该实践指导路径清晰、可操作，能有效提升文本细读与论证能力，适用于不同层次的本科文学课程，建议在教学中持续迭代提问与写作任务。
#
# 当前分类：文学小说，分类结果：('文学小说', '理由：文本内容围绕文学作品《了不起的盖茨比》的教学案例展开，涉及人物形象塑造、故事情节分析和具体环境描绘，旨在通过教学提升学生的文本细读与论证能力，符合文学小说通过艺术手段反映社会生活的定义。')
# ==============================
# 合成数据：{
# "tone_check": "导师的指导风格温和且鼓励。",
# "structure": [
# "例如：：场景，描述主角在图书馆偶遇暗恋对象的日常细节。",
# "例如：：冲突，主角因误会而产生内心矛盾，影响学习状态。",
# "例如：：成长，主角通过沟通或自我调整，获得情感成熟。"
# ],
# "dialogue_demo": "导师说：写出心跳加速的瞬间，保持真实。",
# "assignment": "请写一篇300字的校园暗恋短篇，明晚提交。"
# }。
#
# 当前分类：青春文学，分类结果：('文学小说', '理由：文本内容涉及文学创作指导，包括场景描写、冲突构建和人物成长等小说创作要素，符合文学小说通过塑造人物形象、构建故事情节来反映社会生活的定义。')
# ==============================
# 合成数据：案例：孩子想买昂贵玩具，家长引导：“为何喜欢？广告如何说服你？有无更好替代？”孩子分析广告话术与性价比，最终选了更优方案。
# 策略优势：激发主动思考，提升决策与问题解决力。过度质疑或致钻牛角尖，需引导孩子尊重事实与他人观点。
# 实践步骤：1.多用“为何/如何/假如”提问；2.鼓励孩子找证据；3.讨论不同观点；4.复盘思考过程。
# 共同练习：选一则新闻，与孩子讨论“谁说的？证据何在？有无其他可能？”，画出逻辑链。
# 评估方法：观察孩子能否主动提问、区分事实观点、逻辑清晰表达。定期记录并对比表现。
# 总结：批判性思维是核心竞争力。家长需以身作则，将提问融入生活，鼓励反思，灵活应用于不同场景！
#
# 当前分类：亲子育儿，分类结果：('家庭教育', '理由：文本内容围绕家长如何通过提问引导孩子分析问题、培养批判性思维，涉及亲子互动、教育方法和成长引导，符合“家庭教育”中聚焦家庭环境中对子女的教育理念、方式的定义。')
# ==============================
# 合成数据：《水经注》里的“河水”，指的就是咱们的母亲河——黄河！这可不是一本枯燥的流水账，而是一场穿越时空的地理大冒险。郦道元这位硬核博主，用生花妙笔把黄河从源头到入海的壮丽行程描绘得活灵活现。
#
# 书里说黄河发源于昆仑山，那可是神话级别的“天庭水源”。河水一路奔腾，像个调皮的孩子，时而潜入地下玩捉迷藏，时而冒出地面撒欢。最精彩的是对“龙门”的描写，大禹治水劈开大山，黄河冲破束缚，那场面简直是地质级的“速度与激情”，水浪拍岸如雷鸣，连鱼儿都得练跳高才能“跃龙门”。
#
# 他还顺带科普了沿岸的奇闻异事，比如哪里水清如镜，哪里浊浪排空。这不仅是地理笔记，更是生态观察报告。黄河的“黄”，正是它携带的黄土高原泥沙，像给大地盖了层厚厚的棉被。
#
# 《水经注》用严谨的考证和生动的文笔，把一条大河写成了有性格、有故事的主角。它告诉我们，黄河的每一次改道与泛滥，都是大自然在书写自己的历史。读懂河水，就读懂了中华大地的脉搏与沧桑。这就是黄河，一条流淌在古籍里的金色巨龙！
#
# 当前分类：古籍地理，分类结果：('古籍地理', '理由：文本围绕《水经注》展开，介绍了黄河的源头、流向、地貌特征及历史典故，属于描述地域自然与人文风貌的古籍整理与解读，符合“古籍地理”分类中关于线装书、学术整理本及地域风貌描述的定义。')
# ==============================
# 合成数据：{"role":"经济管理领域教育者","title":"数据驱动的专业能力跃迁：给学生的成长指南","content":"专业能力提升并非玄学，而是可量化、可追踪的系统工程。核心在于将抽象目标拆解为具体动作，并用数据反馈闭环。作为你们的老师，我建议用三个关键指标来度量成长，让每一次努力都看得见。","metrics":[{"metric":"月度精读文献数","value":"≥10篇"},{"metric":"案例分析完成量","value":"≥8个/学期"},{"metric":"课堂/社群讨论参与度","value":"≥20次/学期"}],"action_plan":["每周固定3小时精读顶级期刊文献，提炼1页核心观点笔记。","每两周完成1个真实商业案例分析，形成结构化复盘报告。","每月至少参与2次跨学科研讨，主动提出1个批判性问题。","建立个人知识库，将所学内容整理为可复用的方法论。","每季度进行一次自我评估，对比指标数据并迭代学习策略。"]}。
#
# 当前分类：经济管理，分类结果：('经济管理', '理由：文本围绕专业能力提升、数据驱动、指标量化等概念展开，涉及学习策略与成长路径，符合经济管理中关于组织运作、决策与效率提升的核心思想。')
# ==============================
# 合成数据：作为资深人文社科专家，我认为推动行业发展的核心在于打破学科壁垒，通过跨学科研究培育颠覆性创新。传统单一学科视角已难以应对复杂现实，必须融合社会学、经济学、心理学与数据科学等多领域智慧。这种融合能激发全新思维范式，从根源上重塑行业逻辑，催生更具韧性与前瞻性的解决方案。
#
# 为实现这一目标，我提出以下关键策略与实施路径：
# 策略一：构建“问题导向”的协同平台。打破院系藩篱，围绕具体行业痛点（如可持续发展、数字伦理）组建临时攻关团队，强制不同学科背景成员深度互动。
# 策略二：重塑人才培养与评价体系。在教育中引入跨学科辅修与项目制课程；在评价中降低单一指标权重，增设“跨界协作贡献度”考核，鼓励冒险与试错。
#
# 实施路径需分三步走：
# 第一阶段（1-2年）：设立专项基金，支持高风险、高潜力的跨学科探索项目，建立“创新沙盒”机制。
# 第二阶段（3-5年）：推动产学研深度融合，将学术成果直接导入产业场景进行验证与迭代，形成反馈闭环。
# 第三阶段（5年以上）：建立跨学科数据库与知识共享网络，将成功模式制度化，确保创新生态的自我进化与持续繁荣。这一系统性工程将为行业注入不竭动力！
#
# 当前分类：人文社科，分类结果：('人文社科', '理由：文本聚焦于通过跨学科研究推动行业发展，涉及社会学、经济学、心理学等多领域融合，探讨学科壁垒打破、人才培养体系改革及产学研结合等系统性社会议题，符合人文社科研究人类文化、社会现象及思想传承的定义。')
# ==============================
# 合成数据：近期，詹姆斯·韦伯空间望远镜（JWST）在系外行星WASP-39b的大气中明确探测到二氧化碳的存在。该发现的关键数据来自JWST的近红外光谱仪（NIRSpec）在2022年8月获取的光谱。光谱数据显示了二氧化碳分子在4.1至4.6微米波段的显著吸收特征，其丰度约为大气总量的万分之一。该成果于2022年11月发表于《自然》杂志，标志着人类首次在太阳系外的行星大气中清晰识别出该气体。
#
# 研究团队通过透射光谱法进行了观测。当WASP-39b掠过其母恒星前方时，恒星光线穿过行星大气层，特定波长的光被大气中的二氧化碳分子吸收，从而在光谱上留下独特的“指纹”。科学家随后利用高精度的大气化学与辐射传输模型对光谱数据进行反演，排除了其他解释，最终确认了二氧化碳的存在及其丰度。
#
# 此项发现对系外行星科学具有深远影响。二氧化碳是碳循环的关键组分，其探测为构建WASP-39b的详细大气化学模型提供了核心数据，有助于推断该行星的形成历史与演化路径。更重要的是，JWST展现的超高灵敏度为后续探测类地行星大气中的生物特征气体（如氧气、甲烷）奠定了坚实基础，极大地推进了在宜居带行星上寻找生命迹象的能力。
#
# 当前分类：自然科学，分类结果：('自然科学', '理由：文本详细介绍了詹姆斯·韦伯空间望远镜对系外行星大气中二氧化碳的探测过程、方法及其科学意义，属于对自然界现象及其规律的研究，符合“自然科学”的定义。')
# ==============================
# 合成数据：预算有限下的高质量周末短途旅行规划旨在以有限资源获得优质体验。目标是控制总花费，同时兼顾交通、住宿、餐饮与休闲的平衡与满意度。
#
# 步骤分解：
# 1. 目的地与时机：优先选择邻近城市或自然景区，利用非高峰时段出行。预算示例：选择高铁二等座或拼车，人均交通费控制在100元以内。
# 2. 交通与住宿：使用公共交通或自驾分摊油费，住宿选择青年旅舍、民宿或经济连锁酒店，多人合住更省。预算示例：住宿控制在150元/人/晚。
# 3. 餐饮与活动：以当地特色小吃与超市补给为主，活动优先免费或低收费景点。预算示例：餐饮控制在80元/天，门票选择免费公园或博物馆。
# 4. 行程与预订：提前2周规划路线并预订，利用平台优惠券与早鸟价，制定弹性行程。预算示例：使用优惠券节省20%费用。
#
# 常见挑战及应对：
# - 恶劣天气：准备室内备选方案，如图书馆、展览馆。
# - 人流拥挤：错峰出行或选择冷门路线，提升体验。
#
# 预期成果：在人均预算300-500元内实现舒适交通、安心住宿、特色餐饮与丰富活动，获得高性价比的周末短途旅行。
#
# 当前分类：旅游休闲，分类结果：('旅游休闲', '理由：文本详细介绍了如何在预算有限的情况下规划高质量的周末短途旅行，涵盖了目的地选择、交通住宿、餐饮活动及预订策略等实用建议，旨在为读者提供旅行灵感和具体指导，符合“旅游休闲”分类中“为旅行或日常休闲活动提供信息、灵感或指导”的定义。')
# ==============================
# 合成数据：案例背景介绍：安迪·沃霍尔的《金宝汤罐头》（Campbell's Soup Cans, 1962）是波普艺术里程碑，反映了消费主义与大众文化。市场表现强劲，拍卖价可达数百万美元。常见伪造特征包括：丝网印刷套色不准、颜料过厚或不均、签名位置或笔画不符惯例。
#
# 鉴赏步骤与实践指导：
# 1. 视觉检查：观察笔触是否机械而均匀，真迹常有细微不规则；检查颜料层，老化应有自然裂纹而非人为刮痕；核对签名，沃霍尔签名多为“Andy Warhol”且风格一致。
# 2. 材料分析：确认画布为1960年代亚麻布，底漆均匀；检查背面标签或画廊标记，真迹常有Castelli Gallery标签。
# 3. 文献考证：核实展览历史与来源链条，要求拍卖行或画廊提供COA（真迹证书）和出版记录。
# 实践步骤：使用放大镜和紫外线灯检查；咨询专业鉴定师；比对已知真迹图像；索取完整档案。
#
# 最终结论与购买建议：若视觉、材料与文献均一致且来源清晰，建议在专业拍卖行竞标此作品；若任何环节存疑，建议暂缓收藏并要求更多鉴定报告。通过系统化的鉴赏流程，收藏者可以显著降低风险并提升收藏价值。
#
# 当前分类：艺术收藏，分类结果：('艺术收藏', '理由：文本详细介绍了安迪·沃霍尔作品的鉴赏步骤、伪造特征识别及收藏建议，涉及艺术品鉴定、市场分析和收藏指南，符合“艺术收藏”分类中关于鉴赏知识与收藏指南的定义。')
# ==============================
# 合成数据：大家好，欢迎来到今天的分享。让我们一起探索自己的闪光点，找到属于你的独特优势。
#
# *   **第一步：回顾“小成就”**。请回忆最近一周，有没有哪件事让你感到开心或有成就感？比如，你是否帮助同学解决了难题？是否在运动会上为班级争光？或者，你是否独立完成了一项手工制作？写下这件事，它能帮你找到优势的线索。
#
# *   **第二步：寻找“行为模式”**。观察你写下的这件事，思考你当时具体做了什么？是耐心地讲解，还是勇敢地尝试？是细致地观察，还是热情地鼓励他人？把这些具体的行为记录下来，它们就是你优势的体现。
#
# *   **第三步：记录“我的优势”**。现在，请用一句话来总结你的优势。例如：“我有很强的共情能力，能敏锐察觉朋友的情绪变化。”或者“我做事有条理，能将复杂的任务分解成小步骤完成。”请把它清晰地写在你的笔记本上。
#
# *   **第七天微小实践计划**：在接下来的7天里，请至少有一次，主动运用你的优势去完成一件小事。比如，如果你的优势是“乐于助人”，可以主动帮家人做一次家务；如果是“善于发现细节”，可以记录下身边三个有趣的细节。期待你的发现！
#
# 当前分类：励志成长，分类结果：('励志成长', '理由：文本通过引导读者回顾成就、识别行为模式、总结个人优势并制定实践计划，旨在激励个人自我认知与成长，符合励志成长的定义。')
# ==============================
# 合成数据：主流育儿理念各有局限。“温和管教”易滑向放任，忽视边界；“奖惩机制”则可能异化为控制，扼杀内驱力。常见误区是将“温和”等同于“无规则”，或把“奖惩”简化为“交易”。优化的关键在于从“控制”转向“合作”，建立“连接-引导-赋能”的框架。
#
# 案例一：孩子拖延作业。家长不催促责备（温和），也不直接奖励完成（奖惩），而是共情其畏难情绪（连接），引导拆解任务并设定番茄钟（引导），最后肯定其专注过程（赋能）。
#
# 案例二：兄妹争执玩具。家长不裁决对错（奖惩），也不空泛说教（温和），而是先分开双方让其冷静（连接），引导各自表达诉求并共同商议轮流方案（引导），事后复盘肯定其沟通努力（赋能）。此框架将规则内化为共同约定，将激励聚焦于成长本身。
#
# 当前分类：家庭教育，分类结果：('亲子育儿', '理由：文本围绕育儿理念展开，分析了“温和管教”与“奖惩机制”的局限性，并提出了基于“连接-引导-赋能”框架的具体育儿案例（如处理孩子拖延、兄妹争执），旨在指导父母如何与孩子互动并解决育儿难题，符合“关注父母与子女互动关系，提供育儿理念、方法和指导”的定义。')
# ==============================
# 合成数据：作为深耕两性关系领域十余年的专家，我常被问及：激情褪去后，什么决定了长期伴侣的幸福？答案并非简单的“爱”，而是更深层的互动模式。
#
# 首先，积极的沟通与建设性冲突处理是基石。美国戈特曼研究所（Gottman Institute）的研究揭示了一个残酷的分水岭：在预测离婚时，消极互动与积极互动的比例若超过5:1，关系破裂的风险将急剧上升。这意味着，日常的微小善意与包容，是抵御矛盾冲击的缓冲垫。
#
# 其次，共同成长与保持新鲜感至关重要。长期关系最大的误区是“停滞”。当一方在飞速成长，而另一方原地踏步，裂痕便会产生。伴侣应是彼此的“成长合伙人”，支持对方的自我实现，同时共同探索新体验，为生活注入活力。
#
# 最后，情绪价值的提供是现代关系的刚需。在高压社会下，伴侣能否成为彼此的安全港湾，决定了关系的粘性。这不仅仅是陪伴，更是深度的共情与理解。
#
# 因此，长期伴侣关系的满意度，本质上取决于双方是否能保持建设性的沟通、支持彼此成长并提供持续的情绪支持。
#
# 当前分类：两性关系，分类结果：('两性关系', '理由：文本深入探讨了长期伴侣关系中激情褪去后的维系要素，包括沟通、共同成长和情绪价值，符合两性关系定义中关于恋爱、婚姻、家庭中男性与女性互动、情感及社会关系的探讨。')
# ==============================
# 合成数据：欢迎加入“可持续时尚”“7天胶囊衣橱挑战”！请按以下指南执行：
#
# **1. 选衣标准（3选1）：**
# *   **极简版**：上衣≤5件，下装≤3件，外套≤1件。
# *   **功能版**：单品≤10件，需覆盖通勤、运动、休闲场景。
# *   **色彩版**：仅选3种主色调的单品，确保任意两件可搭配。
#
# **2. 每日搭配公式：**
# 遵循“1+2+1”法则：
# *   **1**件核心单品（如连衣裙、连体裤）。
# *   **2**件辅助单品（如外套+裤子，或上衣+半裙）。
# *   **1**件点睛配饰（如丝巾、腰带、耳环）。
#
# **3. 旧衣改造实操：**
# **项目**：旧T恤变环保托特包。
# **工具清单**：剪刀、直尺、针线（或缝纫机）、大头针。
# **步骤**：剪去袖子和领口（包口）；底部内折2cm缝合（包底）；将多余布料编成两条长辫子，缝合在包口两侧作提手。
#
# **4. 误区解决方案：**
# **误区**：“极简=单调”。
# **方案**：利用“叠穿”与“配饰”增加层次感。例如，将衬衫作为内搭，外搭针织马甲，再配一条亮色丝巾，既保暖又丰富视觉效果。
#
# 祝挑战成功，拥抱可持续生活！
#
# 当前分类：生活时尚，分类结果：('生活时尚', '理由：文本围绕“胶囊衣橱”、“旧衣改造”和“时尚搭配”展开，旨在通过具体的穿搭法则和改造技巧提升个人生活品味与外在形象，符合“生活时尚”关注消费潮流与生活方式的定义。')
# ==============================
# 合成数据：2025年，全球地缘政治格局将围绕大国军事技术竞赛与能源安全的深度捆绑而演变。高超音速武器与AI赋能的自主作战系统正重塑攻防平衡，削弱传统战略威慑的有效性。大国对关键航道与能源产地的争夺，将加剧印太、中东等区域的“灰色地带”冲突动态。
#
# 实现“可持续”稳定需两条路径：一是建立大国间危机管控机制，明确“红线”避免误判；二是构建多元化的能源供应链，降低单一地缘节点的战略脆弱性。
#
# 未来十年全球军费开支将维持约5%的年均增长。核心驱动因素包括：为应对大国竞争而进行的军事现代化升级、能源供应链的防御性部署，以及人工智能与太空等新兴作战域的高昂研发投入。
#
# 当前分类：政治军事，分类结果：('政治军事', '理由：文本分析了全球地缘政治格局、大国军事技术竞赛、能源安全、军费开支增长等，涉及国家治理、国际关系、国防、战略战术等，符合政治军事分类定义。')
# ==============================
# 合成数据：案例：某制造企业数字转型受阻。目标人群：中层管理者与一线骨干。实施流程：1.诊断与愿景对齐；2.试点选型；3.培训与试运行；4.全链推广。资源配置：项目经理1名、数据工程师2名、业务代表3名、预算20万。时间表：第1-2周诊断，第3-6周试点，第7-10周培训推广，第11-12周复盘。风险应对：阻力大时开展一对一访谈；数据不一致时建立清洗规则；进度滞后时调整试点范围并增加晨会。
#
# 可复用步骤：组建跨职能小组，绘制价值流图，设定小目标，建立数据看板，开展用户反馈会，迭代优化。评估指标与验证方法：流程周期缩短率（周期时间对比）、缺陷率（质检数据）、员工采纳率（系统日志）、客户满意度（问卷）。验证：A/B测试、前后对比、第三方抽样。
#
# 检查清单：目标明确、干系人就位、数据可得、培训材料齐备、试点范围清晰、反馈机制畅通、复盘计划就位。
#
# 结论：该方案可执行且可复制，按步骤推进可实现预期改进。
#
# 当前分类：其他分类，分类结果：('经济管理', '理由：文本内容围绕企业数字化转型的实施流程、资源配置、风险应对及评估指标展开，涉及项目管理、组织变革和运营优化，符合经济管理分类中关于组织机构有效运作和决策的定义。')
# ==============================
# 合成数据：《高效外语学习行动指南》
#
# 一、目标设定原则：以终为始，精准导航。
# 核心理念：将宏大愿景转化为可量化、可追踪的阶段性目标，确保行动方向清晰。
# 操作建议：
# 1. 使用SMART法则设定每周听说读写任务。
# 2. 将大目标拆解为每日“微目标”，如背20词、听10分钟。
# 3. 建立可视化进度看板，定期复盘调整。
# 误区警示：避免设定模糊且无法衡量的目标。
#
# 二、输入优先原则：海量可理解输入。
# 核心理念：在输出前，通过大量听读积累语感与素材，建立语言直觉。
# 操作建议：
# 1. 选择略高于当前水平的i+1材料。
# 2. 每日坚持“碎片化”听力浸泡，如通勤泛听。
# 3. 进行精读训练，积累高频词块与句型。
# 误区警示：切忌盲目堆砌输入量而忽视理解度。
#
# 三、刻意练习原则：走出舒适区。
# 核心理念：聚焦薄弱环节进行高强度、有反馈的专项训练，而非简单重复。
# 操作建议：
# 1. 针对发音弱点，进行最小对立体辨音训练。
# 2. 限时阅读，提升处理复杂长难句的速度。
# 3. 模仿跟读高难度语段，直至脱稿复述。
# 误区警示：警惕“舒适区”内的低效重复。
#
# 四、反馈修正原则：即时纠错与迭代。
#
# 当前分类：外语学习，分类结果：('外语学习', '理由：文本内容围绕外语学习的目标设定、输入积累、刻意练习和反馈修正等核心方法展开，提供了具体的操作建议和误区警示，完全符合“以教授外语或帮助提升外语能力为核心目的”的外语学习分类定义。')
# ==============================
# 合成数据：法律哲学社区讲稿：循循善诱的法律思考
#
# ## 法与道德的关系
# 大家好，法律与道德常被比作两条并行的河流，有时汇合，有时分叉。在多数法域，法律是道德的底线，但并非全部道德要求都会入法。
#
# 案例1：一位青年因饥饿窃取面包被抓。
# 争议焦点：生存需求是否可阻却违法？
# 启发：道德同情与法律规则需要平衡。
#
# 案例2：企业拒绝为员工提供宗教假期。
# 争议焦点：宗教道德与雇佣规则如何协调？
# 启发：宽容与秩序需要制度安排。
#
# 你会如何权衡个人道德直觉与法律规则？请思考：社会共识、权利边界与后果评估。
#
# ## 法律解释的方法论
# 我们接着探讨，法律解释如同阅读多层文本，需兼顾字面、目的与体系。法官通常在文义与目的之间穿梭，避免机械适用。
#
# 案例1：合同规定“不可抗力”免责，突发疫情是否适用？
# 争议焦点：文义与目的如何统一？
# 启发：解释应贴合现实与公平预期。
#
# 案例2：交通法禁止“车辆”进入公园，电动滑板车算吗？
# 争议焦点：概念边界与立法意图如何判断？
# 启发：解释需结合上下文与社会常识。
#
# 如果你是法官，会优先采用哪种解释方法？请思考：可预测性、社会效果与权利保护。
#
# 当前分类：法律哲学，分类结果：('法律哲学', '理由：文本围绕法理、法律制度及法律条文展开，探讨了法与道德的关系、法律解释方法论等核心法律哲学问题，符合分类定义中“阐述法理、法律制度、法律条文”的描述。')
# ==============================
# 合成数据：第一部分：问题诊断与需求分析。小户型痛点是物品多、面积小、动线乱。机构经验：先做“物品审计”，按“常用/季节/低频”分类，剔除冗余。建议1：绘制平面与立面收纳地图，标注高频区（玄关、厨房、卧室床头），识别闲置死角。建议2：设定储物目标与容量上限，如“每区域预留20%弹性”，防止过度填充导致美观失衡。
#
# 第二部分：具体策略与产品推荐。策略核心是“立体扩容+模块化+视觉减负”。建议1：利用垂直与顶部空间，推荐顶天立地柜、床下带抽收纳盒、门后挂钩；柜内用可调节层板与伸缩杆，提升利用率。建议2：多功能家具与模块化组件，推荐带抽屉的榻榻米、可伸缩餐桌、壁床或折叠桌；视觉上选浅色哑光面板、隐藏拉手，保持整洁感。
#
# 第三部分：实施步骤与维护建议。步骤：1）按“就近收纳”原则，将物品放入使用场景最近的柜体；2）统一收纳容器（透明/标签），建立“一进一出”规则。维护：每月复盘一次，按季节调整；每季度检查五金件与层板承重，及时加固。机构经验：收纳是生活方式，设计要随居住者习惯迭代。
#
# 核心要点：以“立体扩容+模块化+视觉减负”实现小户型高效储物与美观并重。
#
# 当前分类：家居生活，分类结果：('家居生活', '理由：文本围绕小户型收纳痛点，提供了从问题诊断、策略推荐到实施维护的系统性解决方案，包括物品分类、空间规划、家具选择和日常维护等实用建议，完全符合“提供关于改善居家环境、提升日常生活品质的实用建议和灵感”的定义。')
# ==============================
# 合成数据：0-3岁可持续养育：基于分析的早期发展支持指南
#
# 现状分析
# 0-3岁大脑发育高度可塑，养育环境对神经回路的塑造至关重要。许多家庭与机构虽投入大量精力，却因缺乏数据驱动的分析，导致互动低效、回应迟滞，阻碍儿童潜能的持续增长。常见问题包括：回应式照护缺失、语言输入单一、流程不稳定。
#
# 可持续策略
# 核心是建立可长期坚持的微习惯，而非短期干预。策略一：回应式照护与语言输入。看护人需在婴儿发出声音或动作后2秒内给予温暖回应，并进行“平行描述”与“开放式提问”，将日常照料转化为语言学习场景。策略二：可预测的日常流程与情绪脚手架。在托育机构中，建立固定的过渡仪式（如“预告-共情-选择”三步法），帮助幼儿在活动切换前获得掌控感与安全感。策略三：环境优化。减少过度刺激，提供可探索的安全区，支持自主游戏。
#
# 案例
# 案例一：小月龄家庭。父母通过分析发现婴儿微笑多在抚触时出现，遂将每日抚触时间固定为10分钟，并在此期间高频对视与模仿发音。3个月内，婴儿的社交微笑频率提升50%，对声音的模仿反应从每周2次增至10次。
# 案例二：托育机构。
#
# 当前分类：孕产育儿，分类结果：('亲子育儿', '理由：文本聚焦于0-3岁婴幼儿的养育环境、互动方式及发展支持策略，提供了具体的育儿方法和案例分析，符合亲子育儿关注父母与子女互动关系及提供育儿理念、方法和指导的定义。')
# ==============================
